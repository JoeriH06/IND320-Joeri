# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <h1 id="important-information">Important Information</h1>
#
# - All formatting in this project has been applied manually.
# - The formatting style is based on the guidelines from:
#   <a href="https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet" target="_blank">
#   IBM Jupyter Markdown Cheatsheet
#   </a>
# - This document will include topics such as:
#     - A brief description of AI usage.
#     - A 300-500-word log describing the compulsory work and my experience.
#     - A link to my public GitHub repository and streamlit app
#     - A Table of contents with links to the place in the document
#
# - My GitHub repository: [My GitHub Repository](https://github.com/JoeriH06/IND320)
# - My Streamlit app: [My streamlit App](https://joerih06-ind320-joeri-streamlithome-cczwtx.streamlit.app/)
# </div>

# %% [markdown]
# <div style="
#   background:#f2f6fa;                   /* soft light-gray-blue background */
#   border-left:8px solid #0b3d91;        /* deep navy accent */
#   padding:22px 28px;
#   border-radius:10px;
#   box-shadow:0 2px 6px rgba(0,0,0,0.1);
#   font-family:Georgia,'Book Antiqua','Palatino Linotype',serif;
#   color:#0d1b2a;
# ">
#
# <h1 style="
#   color:#b87333;                        /* bronze title */
#   font-size:2.2em;
#   font-weight:700;
#   margin-top:0;
#   margin-bottom:0.4em;
# ">
#   🤖 AI&nbsp;Usage
# </h1>
#
# <p style="
#   font-size:1.1em;
#   color:#1a1a1a;
#   margin-top:0;
#   margin-bottom:1em;
#   text-align:justify;
# ">
#   This project included selective use of AI tools to support learning, debugging,
#   and documentation.<br>
#   Below is a transparent description of when and how AI assistance was used.
# </p>
#
# <ul style="line-height:1.55;margin-top:0;margin-bottom:0;">
#   <li><strong>Looking up errors:</strong><br>
#       When encountering error messages I did not understand after reading them,
#       I asked AI to explain their meaning and possible causes.<br>
#       In some cases, I implemented the suggestions provided; in others, I
#       preferred to verify solutions independently through web searches or
#       documentation.</li>
#
#   <li style="margin-top:0.8em;"><strong>Re-writing and proofreading:</strong><br>
#       Writing documentation can be challenging.
#       I first drafted my own takeaways, explanations, and reflections, then
#       asked AI to help check spelling, grammar, and sentence flow.<br>
#       The re-phrasing stayed close to my original wording, keeping my opinions
#       and interpretation intact.
#       Minor spelling errors or stylistic differences may remain intentionally.</li>
#
#   <li style="margin-top:0.8em;"><strong>Writing cell documentation:</strong><br>
#       Writing cell documentation is difficult in way for everyone to understand.<br>
#       I used AI to help me and write clear and instructive documentation for the code used in the cells.
#       </li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="
#   background:#edf3fa;                   /* soft light-blue background */
#   border-left:8px solid #0b3d91;        /* deep navy border */
#   padding:22px 28px;
#   border-radius:10px;
#   box-shadow:0 2px 6px rgba(0,0,0,0.1);
#   font-family:Georgia,'Book Antiqua','Palatino Linotype',serif;
#   color:#0d1b2a;
# ">
#
# <h1 style="
#   color:#b87333;                        /* bronze title */
#   font-size:2.2em;
#   font-weight:700;
#   margin-top:0;
#   margin-bottom:0.4em;
# ">
#   ✨ Personal Takeaways
# </h1>
#
# <p style="
#   font-size:1.1em;
#   color:#1a1a1a;
#   margin-top:0;
#   margin-bottom:1em;
#   text-align:justify;
# ">
#   This assignment expanded on earlier project work by combining <strong>API integration</strong>,<br>
#   <strong>data analysis</strong>, and <strong>dashboard development</strong> into a single, coherent workflow.<br>
#   The process taught me to connect several technologies – Open-Meteo, Pandas, and Streamlit – in a practical and reproducible way.<br>
# </p>
#
# <ul style="line-height:1.6;margin:0 0 1em 0;">
#   <li><strong>Improved Data Handling:</strong><br>
#       I learned how to retrieve and structure external datasets through APIs instead of static CSV files,<br>
#       and to design flexible download functions for reuse across cities and years.</li>
#
#   <li><strong>Analytical Techniques:</strong><br>
#       Implementing <em>Direct Cosine Transform</em>, <em>STL decomposition</em>, and <em>Local Outlier Factor</em><br>
#       helped me understand practical anomaly-detection and seasonal-trend methods.</li>
#
#   <li><strong>Visualization & Interpretation:</strong><br>
#       Combining temperature, precipitation, and production data in clear visual plots made me more aware<br>
#       of the importance of communication in analytics – not just computation.</li>
#
#   <li><strong>Integration with Streamlit:</strong><br>
#       Expanding the Streamlit app and managing page order, interactivity, and caching<br>
#       gave me hands-on experience with web deployment and user interface design for analytical tools.</li>
#
#   <li><strong>Version Control & Workflow:</strong><br>
#       Working through GitHub branches for temporary updates<br>
#       reinforced how valuable structured versioning is for collaboration and assessment cycles.</li>
# </ul>
#
# <p style="
#   font-size:1.05em;
#   color:#1a1a1a;
#   text-align:justify;
#   margin-top:1em;
# ">
#   Overall, this project connected the technical and creative aspects of data science –<br>
#   from engineering the data pipeline to presenting insights visually.<br>
#   It strengthened both my analytical reasoning and my ability to design maintainable, user-friendly tools.
# </p>
#
# </div>
