# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# Load data from the Silver layer
silver_in = Path("../Data_assignment_1/silver/open_meteo_clean.csv")
data = pd.read_csv(silver_in)

# %%
print("Dtypes:\n", data.dtypes, "\n")
print("Nulls per column:\n", data.isna().sum(), "\n")
display(data.head(3))
# Out:
# Dtypes:
#  time                       object
# temperature_2m_(°c)       float64
# precipitation_(mm)        float64
# wind_speed_10m_(m/s)      float64
# wind_gusts_10m_(m/s)      float64
# wind_direction_10m_(°)      int64
# dtype: object
#
# Nulls per column:
#  time                      0
# temperature_2m_(°c)       0
# precipitation_(mm)        0
# wind_speed_10m_(m/s)      0
# wind_gusts_10m_(m/s)      0
# wind_direction_10m_(°)    0
# dtype: int64
#                time  temperature_2m_(°c)  precipitation_(mm)  \
# 0  2020-01-01T00:00                 -2.2                 0.1
# 1  2020-01-01T01:00                 -2.2                 0.0
# 2  2020-01-01T02:00                 -2.3                 0.0
#
#    wind_speed_10m_(m/s)  wind_gusts_10m_(m/s)  wind_direction_10m_(°)
# 0                   9.6                  21.3                     284
# 1                  10.6                  23.0                     282
# ...

# %%
# Convert time column to datetime
data["time"] = pd.to_datetime(data["time"], errors="coerce")

# Plot each numeric column against time
for column in data.columns:
    # skip the time column itself
    if column != "time":
        plt.figure(figsize=(10, 4))
        plt.plot(data["time"], data[column])
        plt.title(column)
        plt.xlabel("Time")
        plt.ylabel(column)
        plt.xticks(rotation=45)
        plt.tight_layout()
        plt.show()
